# %% [markdown]
# # Donate compute to Bull4Life
# Set your email below, then **Runtime → Run all**. Keep this tab open — it donates while it runs (Colab ~12h, Kaggle ~9h). Log in at bull4life.com with the same email to see your stats + rewards.

# %%
EMAIL = "you@example.com"   #@param {type:"string"}  <- your bull4life.com login
NICKNAME = ""              #@param {type:"string"}  <- optional public name
import os
os.environ["B4L_COORDINATOR"] = "https://compute.bull4life.com"
os.environ["B4L_EMAIL"] = EMAIL
os.environ["B4L_NICKNAME"] = NICKNAME
os.environ["B4L_POWER"] = "50"
# !curl -fsSL https://github.com/Bull4Life/bull4life-donate/releases/download/v1.7.0/b4l_node-linux -o b4l_node
# !chmod +x b4l_node
print("Donating as", NICKNAME or "anon", "| account:", EMAIL, "\nLeave this running. Stop the cell to pause.")
# !./b4l_node --run
